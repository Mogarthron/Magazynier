# %%
# pg_path = "Z:/160. ROZKRÓJ PIANEK/160.10 GENERATOR/PIAGEN_wersja_3.83.xlsm"
pg_path = "Z:/450. PLANISTA - ZAOPATRZENIE/PIAGEN_wersja_3.83.xlsm"

generatory_path = "Z:/450. PLANISTA - ZAOPATRZENIE/GENERATORY.db"

# %%
# # USUNIECIE BAZY PIANEK
#from sqlite3 import connect
#cnn = connect(generatory_path)
# #cnn.execute("DELETE FROM baza_PIANKI")
#cnn.execute("DROP TABLE lista_bryl_pianki")
#cnn.commit()
#cnn.close()

# from sqlite3 import connect
# cnn = connect(generatory_path)
# cnn.execute("DELETE FROM baza_PIANKI")
# # cnn.execute("DELETE FROM lista_bryl_pianki")
# cnn.commit()
# cnn.close()

# %% [markdown]
# #Data Cleaning and procesing

# %%
import openpyxl
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %%
pg = openpyxl.load_workbook(pg_path, data_only=True)

# %%
lista_modeli_pianki = dict()
serie_pianek = pg["SERIE"]
for r in serie_pianek:
  if r[0].value != None:
    lis = list()
    for i in range(r[3].value):
      lis.append(str(r[4+i].value))

    lista_modeli_pianki[r[0].value] = "_".join(lis).replace(".", ",")
    # print(r[0].value, r[3].value, "_".join(lis))

del(lista_modeli_pianki["LAGO"])
# lista_modeli_pianki

# %%
lista_modeli_pianki["AMALFI"] = lista_modeli_pianki["AMALFI"] + "_1,5 MEM_3,5 MEM_NW MEM_WN MEM_[RS MEM_RS] MEM_[LA MEM_LA] MEM"
lista_modeli_pianki
# Out:
# {'AMALFI': '1,5_2,5_3_4_][_NT_N124_[LA_[RS_NW_P102x82_P102x102_1,5 MEM_3,5 MEM_NW MEM_WN MEM_[RS MEM_RS] MEM_[LA MEM_LA] MEM',
#  'AVANT': '[1]_[2]_[2,5]_[3]_[3F]_[3,5]_[3,5F]_[1_[1,5_[2_[2,5_[3_[3F_[3,5_[3,5F_1]_1,5]_2]_2,5]_3]_3F]_3,5]_3,5F]_1_1,5_2_2,5_3_3,5_N_[LM_[L_LM]_L]_Pufa 110x60_Pufa 114x84_Pufa 104x104_Pufa 114x114_Pufa 64x64_Pufa 84x84_Pufa 104x64_Pufa 112x97_Pufa 112x84_Pufa 112x112_1][_1,5][_2][_2,5][_3][_3F][_3,5][_3,5F][_L][_LM][',
#  'CALYPSO': '1_1,5_2,5_4_][_D_E80D_[L2H_125N_116N_[LA_[LAD_P80x100_P90x100',
#  'COCO': '[1o]_[1M]',
#  'DIVA': 'X1X_X2,5X_X3X_X3,5X_X4X_X5X_2,5X_3X_3,5X_4X_5X_5N_2,5_3_N_LA_[_]_P95x113_P95x95',
#  'DUO': '1_1,5_2_2,5_3_3F_3,5_3,5F_T1,5_N_L][_LH][_Pufa 108x108_Pufa 102x102_Pufa 102x82_Pufa 82x82_Pufa 62x62_][',
#  'ELIXIR': '2,5_3_3,5_4_[_N_Pufa 98x120_Pufa 98x100',
#  'EXTREME': '[1s_[1,5s_[2s_1s_1,5s_2s__[1,5m__1m_1,5m_2m_[Ls_ONs_P80x80_P80x105_P105x105_ZAG Ns_ZAG N125x105_ZAG Nm',
#  'GREY': '[1]',
#  'HUDSON': '2,5_3_3,5_4_][_[L_[LH_ON_NW 149x159_WN 159x149_P103x62_P82x82_P82x62',
#  'HORIZON': '3,5z_3z_2,5z_1,5z_1z_T3,5z_T3z_T2,5z_HOR ][_LOB ][_ONz_[LHz_[L2Hz_117Nz_P102x102_P102x82_P102x62_P82x82_P62x62',
#  'KELLY': '[1]',
#  'LENOX': '[1o]_[1H]',
#  'MAXWELL': '1,5_3_4_ONs_[LH_N_][_P103x92_P103x82_P82x82',
#  'MYSTIC': '2,5_3_3,5_4_2,5N_3N_3,5N_T2,5_T3_T3,5_T4_120N_D_[_Pufa 98x120_Pufa 98x100',
#  'ONYX': '2,5_3_3,5_4_][_N_[LA_N131_P122x102_P102x102',
#  'OVAL': '[1o]',
#  'OXYGEN': '3_3,5_4_L_[L2H_N_P103x80_P103x103_][',
#  'RITZ': '[1]_2,5_3_3,5_4_][_[L_[LH_N_P95x95_P82x82_P103x62_None',
#  'WILLOW': '1_1,5_2,5_4_[_]_[L_[L2Hz_N_P106x106_P82x106_P82x82',
#  'REVERSO': '1_1,5_2_][_L_][ - L_N106x106_T1,5_TE35/103_TE35/82_P106x80_P106x106_P106x120_Ps82x82_Ps82x102_Ps82x122_Ps106x106',
#  'SPECTRA': '2,5z_3z_3,5z_4z_][_[Lz_[L2Hz_P107x103_P86x82',
#  'SAMOA': '[1M]_1_1,5_][_N_Pufa 120x82_Pufa 100x100_Pufa 100x82_Pufa 82x82',
#  'STONE': '1,5_2,5_3_3,5_4_5_ON_NW140x150_WN150x140_[LH_E30_CUPIDO ][_STONE ][_P106x106_P106x82_P82x82_Z50_Z70',
#  'UNO': 'P48x48_P63x63_P78x78'}

# %%
sheet = [x for x in pg.sheetnames if len(x) == 2]
# sheet

# %%
poz = list()

for s in sheet:
  for r in pg[s]:
    # print(r[6].column)
    if r[0].value != None:
      poz.append([x.value for x in r if x.column < 18] + [s])

# %%
df = pd.DataFrame(poz)
df.columns = ["MODEL", "BRYLA", "TYP", "PRZEZ", "OR", "OZN", "PROFIL", "NUMER", "wymiar1", "wymiar2", "ilosc", "obietosc_k", "obietosc_f", "14", "TOLERANCJA" , "16" ,"ile_ciec", "18"]

# %%
df[["obietosc_k", "obietosc_f"]] = df[["obietosc_k", "obietosc_f"]].fillna(0).astype(np.int32)
df.drop(axis=0, index=df[df.MODEL == "NAZWA"].index, inplace=True)

# %%
df[~df.TOLERANCJA.isna()]
# Out:
#          MODEL    BRYLA     TYP      PRZEZ    OR      OZN PROFIL   NUMER  \
# 28         DUO    [3,5]  T-2538     korpus  None   prosta   None  AA0003
# 29         DUO   [3,5F]  T-2538     korpus  None   prosta   None  AA0003
# 305      SAMOA        N  T-2538     korpus  None   profil    P-9  AA0014
# 438      AVANT        2  T-2538     korpus  None   profil   P-12  AA0022
# 439      AVANT      2,5  T-2538     korpus  None   profil   P-12  AA0022
# ...        ...      ...     ...        ...   ...      ...    ...     ...
# 20571  MAXWELL   P82x82   G-401  siedzisko  None   format   None  FA0101
# 20572  MAXWELL  P103x82   G-401  siedzisko  None   format   None  FA0205
# 20573  MAXWELL  P103x92   G-401  siedzisko  None   format   None  FA0206
# 20574     COCO     [1M]   G-401  siedzisko  None  szablon  P-197  FA0375
# 20575     COCO     [1o]   G-401  siedzisko  None  szablon  P-196  FA0376
#
#            wymiar1      wymiar2 ilosc  obietosc_k  obietosc_f  \
# 28     10x160x1800         None     1     2880000     2880000
# 29     10x160x1800         None     1     2880000     2880000
# 305           None   70x100x500     1     2369520     3500000
# 438           None   80x100x600     2     3245059     4800000
# 439           None   80x100x600     2     3245059     4800000
# ...            ...          ...   ...         ...         ...
# 20571         None   50x800x800     1    29525333    32000000
# 20572         None  50x800x1000     1    36400000    40000000
# 20573         None  50x900x1000     1    40950000    45000000
# 20574         None   50x930x931     1    34596000    43245000
# 20575         None   50x668x744     1    19760640    24700800
#
#                                        14   TOLERANCJA    16 ile_ciec  18
# 28                                   None     +/-1x2x5  None        1  AA
# 29                                   None     +/-1x2x5  None        1  AA
# 305    \DOKUMENTACJA\RYSUNKI\A\AA0014.gif     +/-5x5x5  None        2  AA
# 438    \DOKUMENTACJA\RYSUNKI\A\AA0022.gif  +/-10x10x10  None        2  AA
# 439    \DOKUMENTACJA\RYSUNKI\A\AA0022.gif  +/-10x10x10  None        2  AA
# ...                                   ...          ...   ...      ...  ..
# 20571  \DOKUMENTACJA\RYSUNKI\F\FA0101.gif   +/-2x10x10  None        1  FA
# 20572  \DOKUMENTACJA\RYSUNKI\F\FA0205.gif   +/-2x10x10  None        1  FA
# 20573  \DOKUMENTACJA\RYSUNKI\F\FA0206.gif   +/-2x10x10  None        1  FA
# 20574  \DOKUMENTACJA\RYSUNKI\F\FA0205.gif   +/-2x10x10  None        1  FA
# 20575  \DOKUMENTACJA\RYSUNKI\F\FA0206.gif   +/-2x10x10  None        1  FA
#
# [4361 rows x 18 columns]

# %%
df.TOLERANCJA.unique()
# Out:
# array([None, '+/-1x2x5', '+/-5x5x5', '+/-10x10x10', '+/-5x5x10',
#        '+/-1x5x5', '+/-1x5x10', '+/-2x5x5', '+/-2x2x5', '+/-2x2x10',
#        '+/-1x2x2', '+/2x2x5', '+/-2x2x2', 'ZEW', '+/-1x10x5', '+/-1x1x2',
#        '+/-1x1x5', '+/1x2x2', '+/-2x5x10', '+/-1x2x10', '+/-1x3x5',
#        '+/-2x2x5x5', 'SEKTOR', '+/-0x2x5', '+/-2x10x10'], dtype=object)

# %%
df[df.TOLERANCJA == "+/1x2x2"]
# Out:
#        MODEL BRYLA     TYP   PRZEZ    OR     OZN PROFIL   NUMER     wymiar1  \
# 10029  SAMOA   1,5  T-2538  korpus  None  prosta   None  AA1273  10x205x460
#
#       wymiar2 ilosc  obietosc_k  obietosc_f    14 TOLERANCJA    16 ile_ciec  \
# 10029    None     2      943000      943000  None    +/1x2x2  None        1
#
#        18
# 10029  AA

# %%
_tab = df[df.MODEL != "NAZWA"]

# _tab[_tab.ilosc.isna()]

# %%
tab = _tab[~_tab.ilosc.isna()]

# %%
# tab

# %%
def pars_bryla(x):
  if type(x) != str:
    y = str(x)
    y = y.replace(".0", "").replace(".", ",")

    return y
  return x

def pars_ilosc(x):
  if type(x) != int:
    y = np.int32(x)

    return y
  return x

def wymiary(wymiar, format):
  if format == None:
    return wymiar
  elif format != None:
    return format

def wys(wym):
  try:
    if type(wym) != None:
      return int(wym.split("x")[0].replace("***", ""))

    return 0
  except:
    return 0


def szer(s):
  try:
    return int(s.lower().split("x")[-2].replace("*** ", ""))
  except:
    return None

def dlug(d):
  try:
    return int(d.lower().split("x")[-1])
  except:
    return None

tab["BRYLA"] = tab["BRYLA"].apply(pars_bryla)
tab["ilosc"].fillna(0, inplace=True)
tab["ilosc"] = tab["ilosc"].apply(pars_ilosc)
tab["WYMIAR"] = tab.apply(lambda x: wymiary(x.wymiar1,x.wymiar2), axis=1)
tab["WYS"] = tab["WYMIAR"].apply(wys)
tab["SZER"] = tab["WYMIAR"].apply(szer)
tab["DLUG"] = tab["WYMIAR"].apply(dlug)

# %%
tab = tab[tab.MODEL.isin(list(lista_modeli_pianki.keys()))]

# %%
tab[tab.MODEL == "AMALFI"]
# Out:
#         MODEL    BRYLA     TYP      PRZEZ    OR     OZN PROFIL   NUMER  \
# 11705  AMALFI        4  T-2538     korpus  None  prosta   None  AA2750
# 11706  AMALFI        4  T-2538     korpus  None  prosta   None  AA2751
# 11707  AMALFI        4  T-2538     korpus  None  prosta   None  AA2752
# 11708  AMALFI       ][  T-2538     korpus  None  prosta   None  AA2774
# 11709  AMALFI        4  T-2538     korpus  None  prosta   None  AA2753
# ...       ...      ...     ...        ...   ...     ...    ...     ...
# 20542  AMALFI  [RS MEM   G-401     korpus  None  profil  P-181  FA0343
# 20543  AMALFI   NW MEM   G-401     korpus  None  profil  P-182  FA0344
# 20544  AMALFI   NW MEM   G-401     korpus  None  profil  P-183  FA0345
# 20545  AMALFI  LA] MEM   G-401  siedzisko  None  profil  P-184  FA0346
# 20546  AMALFI  LA] MEM   G-401  siedzisko  None  prosta   None  FA0340
#
#            wymiar1       wymiar2  ...  obietosc_f    14  TOLERANCJA    16  \
# 11705   10x40x1000          None  ...      400000  None    +/-1x3x5  None
# 11706   10x95x1100          None  ...     1045000  None    +/-1x5x5  None
# 11707   20x285x940          None  ...     4788000  None    +/-2x5x5  None
# 11708   20x285x740    20x285x740  ...     4218000  None    +/-2x5x5  None
# 11709  10x860x1000          None  ...     8600000  None    +/-1x5x5  None
# ...            ...           ...  ...         ...   ...         ...   ...
# 20542         None    50x925x976  ...    45140000  None  +/-2x10x10  None
# 20543         None   50x800x1185  ...    77974600  None  +/-2x10x10  None
# 20544         None  50x1058x1474  ...    47400000  None  +/-2x10x10  None
# 20545         None   50x610x1340  ...    40870000  None  +/-2x10x10  None
# 20546         None   50x610x1340  ...    40870000  None  +/-2x10x10  None
#
#       ile_ciec  18        WYMIAR WYS  SZER  DLUG
# 11705        1  AA    10x40x1000  10    40  1000
# 11706        1  AA    10x95x1100  10    95  1100
# 11707        1  AA    20x285x940  20   285   940
# 11708        1  AA    20x285x740  20   285   740
# 11709        1  AA   10x860x1000  10   860  1000
# ...        ...  ..           ...  ..   ...   ...
# 20542        1  FA    50x925x976  50   925   976
# 20543        1  FA   50x800x1185  50   800  1185
# 20544        1  FA  50x1058x1474  50  1058  1474
# 20545        1  FA   50x610x1340  50   610  1340
# 20546     None  FA   50x610x1340  50   610  1340
#
# [145 rows x 22 columns]

# %% [markdown]
# #ZAPIS DO BAZY

# %%
from sqlalchemy import create_engine, text, Column, String, Integer, Numeric
# from sqlalchemy.ext.declarative import
from sqlalchemy.orm import sessionmaker, declarative_base

engine = create_engine("sqlite:///"+generatory_path, echo=False)

# %%
tab[['MODEL', 'BRYLA', 'TYP', 'PRZEZ', 'OR', 'OZN', 'PROFIL', 'NUMER','ilosc','WYMIAR', 'WYS', 'SZER', 'DLUG', 'TOLERANCJA']]#.to_sql("baza_PIANKI", con=engine, index=False, if_exists="replace")
#4427 2023-11-06
#4428 2024-02-09
#4432 2024-03-07
#4428 2024-03-18 baza testowa
# Out:
# 4428
