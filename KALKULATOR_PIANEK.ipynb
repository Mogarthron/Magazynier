# %%
from Modele_pianek import *
import warnings
warnings.filterwarnings('ignore')

# %%
tab
# Out:
#         MODEL    BRYLA     TYP      PRZEZ    OR      OZN PROFIL   NUMER  \
# 0         DUO    [3,5]  T-2538     korpus  None   prosta   None  AA0003
# 1         DUO   [3,5F]  T-2538     korpus  None   prosta   None  AA0003
# 2       SAMOA        N  T-2538     korpus  None   profil    P-9  AA0014
# 3       AVANT        2  T-2538     korpus  None   profil   P-12  AA0022
# 4       AVANT      2,5  T-2538     korpus  None   profil   P-12  AA0022
# ...       ...      ...     ...        ...   ...      ...    ...     ...
# 4423  MAXWELL   P82x82   G-401  siedzisko  None   format   None  FA0101
# 4424  MAXWELL  P103x82   G-401  siedzisko  None   format   None  FA0205
# 4425  MAXWELL  P103x92   G-401  siedzisko  None   format   None  FA0206
# 4426     COCO     [1M]   G-401  siedzisko  None  szablon  P-197  FA0375
# 4427     COCO     [1o]   G-401  siedzisko  None  szablon  P-196  FA0376
#
#       ilosc       WYMIAR  WYS  SZER  DLUG
# 0         1  10x160x1800   10   160  1800
# ...

# %%
lista_bryl["MAXWELL"]
# Out:
# ['1,5', '3', '4', 'ONs', '[LH', 'N', '][', 'P103x92', 'P103x82', 'P82x82']

# %%
AMALFI_P({'NW MEM':1}) + MAXWELL_P({'ONs': 5})
# Out:
# {'VITA': 0, 'CIECH': 0, 'PIANPOL': 2.6763996}
